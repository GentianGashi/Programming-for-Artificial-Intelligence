# %% [markdown]
# # Introduction to Programming Artificial Intelligence
#
# ## Class 8 - Manipulating Pandas

# %%
import pandas as pd
df = pd.read_csv ("http://raptor.kent.ac.uk/~ds756/heart.csv")
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# ### Exercise 1
#
# Using the dataframe idiomatically, compute the sum of each feature. Note, this only makes sense for some features. Skip over the ones for which sum is not defined; use the Pandas mechanism for exclusion. The solution should be 1 line.

# %%
df.sum(axis=0, numeric_only=True)
# Out:
# Age              49123.0
# RestingBP       121540.0
# Cholesterol     182498.0
# FastingBS          214.0
# MaxHR           125591.0
# Oldpeak            814.6
# HeartDisease       508.0
# dtype: float64

# %% [markdown]
# ### Exercise 2
# Compute the sum of the sums of the features. Your solution should be 1 line.

# %%
df.sum(axis=0, numeric_only=True).sum()
# Out:
# 480288.6

# %% [markdown]
# ### Exercise 3
# The mode is a measure of centre of a set (as are mean and median). It is the element with the highest frequency.
#
# mode ([4, 4, 1, 5, 5, 5, 7]) = 5 # There are more instances of 5
#
# Implement a function that computes the mode of a column. Name it ComputeMode. It will be invoked as ComputeMode (your_data_frame[“column name”]). You will have to do something to the column before you call your function.
#
# Demonstrate correctness by using it to compute the mode of “Age”.

# %%
def ComputeMode(data):
        return data.mode()    
    
ComputeMode(df["Age"])
# Out:
# 0    54
# dtype: int64

# %%
def ComputeMode(data):
    y={}
    for value in data:
        if not value in y:
            y[value]=1
        else:y[value]+=1
    return [g for g,l in y.items() if l==max(y.values())] 
    
ComputeMode(df["Age"])
# Out:
# [54]

# %%
def ComputeMode(data):
    return max(data.groupby (data).size())
    
ComputeMode(df["Age"])
# Out:
# 51

# %%
def ComputeMode(data):
    return max(data.value_counts())
    
ComputeMode(df["Age"])
# Out:
# 51

# %%
df["Age"].value_counts().index.tolist()[0]
# Out:
# 54

# %%
import matplotlib.pyplot as plt
df['Age'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# #### Exercise 4
# Compute the rate of heart disease by age.

# %%
df[["Age", "HeartDisease"]].groupby (["Age"]).mean()
# Out:
#      HeartDisease
# Age
# 28       0.000000
# 29       0.000000
# 30       0.000000
# 31       0.500000
# 32       0.400000
# 33       0.500000
# 34       0.285714
# 35       0.363636
# 36       0.333333
# 37       0.090909
# 38       0.687500
# 39       0.133333
# 40       0.461538
# 41       0.250000
# 42       0.166667
# 43       0.458333
# 44       0.315789
# 45       0.166667
# 46       0.541667
# 47       0.578947
# 48       0.483871
# 49       0.523810
# 50       0.560000
# 51       0.428571
# 52       0.527778
# 53       0.454545
# 54       0.450980
# 55       0.585366
# 56       0.657895
# 57       0.684211
# 58       0.666667
# 59       0.657143
# 60       0.750000
# 61       0.838710
# 62       0.714286
# 63       0.766667
# 64       0.681818
# 65       0.714286
# 66       0.538462
# 67       0.800000
# 68       0.600000
# 69       0.769231
# 70       0.857143
# 71       0.400000
# 72       0.750000
# 73       1.000000
# 74       0.714286
# 75       0.666667
# 76       0.500000
# 77       1.000000

# %% [markdown]
# #### Exercise 5
# Add a column feature

# %%
df['Feature']='NO DATA'
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Feature
# 0      172              N      0.0       Up             0  NO DATA
# 1      156              N      1.0     Flat             1  NO DATA
# 2       98              N      0.0       Up             0  NO DATA
# 3      108              Y      1.5     Flat             1  NO DATA
# 4      122              N      0.0       Up             0  NO DATA
# ..     ...            ...      ...      ...           ...      ...
# 913    132              N      1.2     Flat             1  NO DATA
# 914    141              N      3.4     Flat             1  NO DATA
# 915    115              Y      1.2     Flat             1  NO DATA
# 916    174              N      0.0     Flat             1  NO DATA
# 917    173              N      0.0       Up             0  NO DATA
#
# [918 rows x 13 columns]
